# %%
import requests
import json

# %%
results = []

# %%
# this is the first query that we are going to use. It retrieves all 
#repositories created after 1 January 2020

q = "created:2019-01-01..2019-12-31"

# %%
#this code uses get method to extract data from github api

#def search_repo_paging(q):

url = 'https://api.github.com/search/repositories'
params = {'q' : q, 'sort' : 'forks', 'order' : 'desc', 
          'per_page' : 100}



while True:
    res = requests.get(url, params = params)
    result = res.json()
    results.extend(result['items'])         #data of result is appended
                                            #to results 
    params = {}
        
    try:
        url = res.links['next']['url']      #through this we get the 
                                            #link of next page.
    except:
        break

# %%
from pandas.io.json import json_normalize
import json
import pandas as pd
import bson.json_util as json_util

# %%
sanitized = json.loads(json_util.dumps(results))

# %%
# Converting the obtained data into a tabular form

normalized = pd.json_normalize(sanitized)

# %%
df = pd.DataFrame(normalized)

# %%
import csv

df.to_csv('Github_repo_data_2019.csv')

# %%
df.columns
# Out:
# Index(['id', 'node_id', 'name', 'full_name', 'private', 'html_url',
#        'description', 'fork', 'url', 'forks_url', 'keys_url',
#        'collaborators_url', 'teams_url', 'hooks_url', 'issue_events_url',
#        'events_url', 'assignees_url', 'branches_url', 'tags_url', 'blobs_url',
#        'git_tags_url', 'git_refs_url', 'trees_url', 'statuses_url',
#        'languages_url', 'stargazers_url', 'contributors_url',
#        'subscribers_url', 'subscription_url', 'commits_url', 'git_commits_url',
#        'comments_url', 'issue_comment_url', 'contents_url', 'compare_url',
#        'merges_url', 'archive_url', 'downloads_url', 'issues_url', 'pulls_url',
#        'milestones_url', 'notifications_url', 'labels_url', 'releases_url',
#        'deployments_url', 'created_at', 'updated_at', 'pushed_at', 'git_url',
#        'ssh_url', 'clone_url', 'svn_url', 'homepage', 'size',
#        'stargazers_count', 'watchers_count', 'language', 'has_issues',
#        'has_projects', 'has_downloads', 'has_wiki', 'has_pages', 'forks_count',
#        'mirror_url', 'archived', 'disabled', 'open_issues_count', 'forks',
#        'open_issues', 'watchers', 'default_branch', 'score', 'owner.login',
#        'owner.id', 'owner.node_id', 'owner.avatar_url', 'owner.gravatar_id',
#        'owner.url', 'owner.html_url', 'owner.followers_url',
#        'owner.following_url', 'owner.gists_url', 'owner.starred_url',
#        'owner.subscriptions_url', 'owner.organizations_url', 'owner.repos_url',
#        'owner.events_url', 'owner.received_events_url', 'owner.type',
#        'owner.site_admin', 'license.key', 'license.name', 'license.spdx_id',
#        'license.url', 'license.node_id', 'license'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 96 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         1000 non-null   int64
#  1   node_id                    1000 non-null   object
#  2   name                       1000 non-null   object
#  3   full_name                  1000 non-null   object
#  4   private                    1000 non-null   bool
#  5   html_url                   1000 non-null   object
#  6   description                767 non-null    object
#  7   fork                       1000 non-null   bool
#  8   url                        1000 non-null   object
#  9   forks_url                  1000 non-null   object
#  10  keys_url                   1000 non-null   object
#  11  collaborators_url          1000 non-null   object
#  12  teams_url                  1000 non-null   object
#  13  hooks_url                  1000 non-null   object
#  14  issue_events_url           1000 non-null   object
#  15  events_url                 1000 non-null   object
#  16  assignees_url              1000 non-null   object
#  17  branches_url               1000 non-null   object
#  18  tags_url                   1000 non-null   object
#  19  blobs_url                  1000 non-null   object
#  20  git_tags_url               1000 non-null   object
#  21  git_refs_url               1000 non-null   object
#  22  trees_url                  1000 non-null   object
#  23  statuses_url               1000 non-null   object
#  24  languages_url              1000 non-null   object
#  25  stargazers_url             1000 non-null   object
#  26  contributors_url           1000 non-null   object
#  27  subscribers_url            1000 non-null   object
#  28  subscription_url           1000 non-null   object
#  29  commits_url                1000 non-null   object
#  30  git_commits_url            1000 non-null   object
#  31  comments_url               1000 non-null   object
#  32  issue_comment_url          1000 non-null   object
#  33  contents_url               1000 non-null   object
#  34  compare_url                1000 non-null   object
#  35  merges_url                 1000 non-null   object
#  36  archive_url                1000 non-null   object
#  37  downloads_url              1000 non-null   object
#  38  issues_url                 1000 non-null   object
#  39  pulls_url                  1000 non-null   object
#  40  milestones_url             1000 non-null   object
#  41  notifications_url          1000 non-null   object
#  42  labels_url                 1000 non-null   object
#  43  releases_url               1000 non-null   object
#  44  deployments_url            1000 non-null   object
#  45  created_at                 1000 non-null   object
#  46  updated_at                 1000 non-null   object
#  47  pushed_at                  1000 non-null   object
#  48  git_url                    1000 non-null   object
#  49  ssh_url                    1000 non-null   object
#  50  clone_url                  1000 non-null   object
#  51  svn_url                    1000 non-null   object
#  52  homepage                   684 non-null    object
#  53  size                       1000 non-null   int64
#  54  stargazers_count           1000 non-null   int64
#  55  watchers_count             1000 non-null   int64
#  56  language                   876 non-null    object
#  57  has_issues                 1000 non-null   bool
#  58  has_projects               1000 non-null   bool
#  59  has_downloads              1000 non-null   bool
#  60  has_wiki                   1000 non-null   bool
#  61  has_pages                  1000 non-null   bool
#  62  forks_count                1000 non-null   int64
#  63  mirror_url                 1 non-null      object
#  64  archived                   1000 non-null   bool
#  65  disabled                   1000 non-null   bool
#  66  open_issues_count          1000 non-null   int64
#  67  forks                      1000 non-null   int64
#  68  open_issues                1000 non-null   int64
#  69  watchers                   1000 non-null   int64
#  70  default_branch             1000 non-null   object
#  71  score                      1000 non-null   float64
#  72  owner.login                1000 non-null   object
#  73  owner.id                   1000 non-null   int64
#  74  owner.node_id              1000 non-null   object
#  75  owner.avatar_url           1000 non-null   object
#  76  owner.gravatar_id          1000 non-null   object
#  77  owner.url                  1000 non-null   object
#  78  owner.html_url             1000 non-null   object
#  79  owner.followers_url        1000 non-null   object
#  80  owner.following_url        1000 non-null   object
#  81  owner.gists_url            1000 non-null   object
#  82  owner.starred_url          1000 non-null   object
#  83  owner.subscriptions_url    1000 non-null   object
#  84  owner.organizations_url    1000 non-null   object
#  85  owner.repos_url            1000 non-null   object
#  86  owner.events_url           1000 non-null   object
#  87  owner.received_events_url  1000 non-null   object
#  88  owner.type                 1000 non-null   object
#  89  owner.site_admin           1000 non-null   bool
#  90  license.key                636 non-null    object
#  91  license.name               636 non-null    object
#  92  license.spdx_id            636 non-null    object
#  93  license.url                479 non-null    object
#  94  license.node_id            636 non-null    object
#  95  license                    0 non-null      float64
# dtypes: bool(10), float64(2), int64(10), object(74)
# memory usage: 681.8+ KB

# %% [raw]
# selecting the columns that are useful for our analysis:
# description, watchers_count, size, forks_count, open_issues_count, language
#
# Out of these description is text and rest is numerical data.
#
# using watchers_count as the criteria to measure popularity of repos

# %% [markdown]
# # Cleaning and Analyzing description of repos

# %%
#removing empty strings in description
df = df.dropna(subset = ['description'])

# %%
#now removing non-english descriptions using langdetect library for detecting the language
from langdetect import detect

type(df['description'])
df['lang'] = df.apply(lambda x: detect(x['description']), axis = 1)

# %%
df.head()
# Out:
#           id                           node_id  \
# 0  177736533  MDEwOlJlcG9zaXRvcnkxNzc3MzY1MzM=
# 1  189621607  MDEwOlJlcG9zaXRvcnkxODk2MjE2MDc=
# 2  228683419  MDEwOlJlcG9zaXRvcnkyMjg2ODM0MTk=
# 3  212094940  MDEwOlJlcG9zaXRvcnkyMTIwOTQ5NDA=
# 4  177216275  MDEwOlJlcG9zaXRvcnkxNzcyMTYyNzU=
#
#                              name  \
# 0                         996.ICU
# 1                            docs
# 2     it-cert-automation-practice
# 3                      DO180-apps
# 4  mslearn-tailspin-spacegame-web
#
#                                       full_name  private  \
# 0                                996icu/996.ICU    False
# 1                                   github/docs    False
# 2            google/it-cert-automation-practice    False
# 3                     RedHatTraining/DO180-apps    False
# 4  MicrosoftDocs/mslearn-tailspin-spacegame-web    False
#
#                                             html_url  \
# 0                  https://github.com/996icu/996.ICU
# 1                     https://github.com/github/docs
# 2  https://github.com/google/it-cert-automation-p...
# 3       https://github.com/RedHatTraining/DO180-apps
# 4  https://github.com/MicrosoftDocs/mslearn-tails...
#
#                                          description   fork  \
# 0  Repo for counting stars and contributing. Pres...  False
# 1           The open-source repo for docs.github.com  False
# 2  Google IT Automation with Python Professional ...  False
# 3           DO180 Repository for Sample Applications  False
# 4  Code used in Microsoft Learn modules to suppor...  False
#
#                                                  url  \
# 0        https://api.github.com/repos/996icu/996.ICU
# 1           https://api.github.com/repos/github/docs
# 2  https://api.github.com/repos/google/it-cert-au...
# 3  https://api.github.com/repos/RedHatTraining/DO...
# 4  https://api.github.com/repos/MicrosoftDocs/msl...
#
#                                            forks_url  ...  \
# 0  https://api.github.com/repos/996icu/996.ICU/forks  ...
# 1     https://api.github.com/repos/github/docs/forks  ...
# 2  https://api.github.com/repos/google/it-cert-au...  ...
# 3  https://api.github.com/repos/RedHatTraining/DO...  ...
# 4  https://api.github.com/repos/MicrosoftDocs/msl...  ...
#
#                            owner.received_events_url    owner.type  \
# 0  https://api.github.com/users/996icu/received_e...          User
# 1  https://api.github.com/users/github/received_e...  Organization
# 2  https://api.github.com/users/google/received_e...  Organization
# 3  https://api.github.com/users/RedHatTraining/re...  Organization
# 4  https://api.github.com/users/MicrosoftDocs/rec...  Organization
#
#   owner.site_admin license.key        license.name license.spdx_id  \
# 0            False       other               Other     NOASSERTION
# 1            False       other               Other     NOASSERTION
# 2            False  apache-2.0  Apache License 2.0      Apache-2.0
# 3            False         NaN                 NaN             NaN
# 4            False       other               Other     NOASSERTION
#
#                                   license.url   license.node_id license lang
# 0                                        None  MDc6TGljZW5zZTA=     NaN   en
# 1                                        None  MDc6TGljZW5zZTA=     NaN   en
# 2  https://api.github.com/licenses/apache-2.0  MDc6TGljZW5zZTI=     NaN   en
# 3                                         NaN               NaN     NaN   en
# 4                                        None  MDc6TGljZW5zZTA=     NaN   en
#
# [5 rows x 97 columns]

# %%
df['lang'].count()
# Out:
# 767

# %%
df.to_csv('Github_repo_data_2019_with_lang_column.csv')
